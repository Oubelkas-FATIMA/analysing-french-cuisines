# %%
# Import libraries
#pi install if not already intalled 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns #Seaborn is a Python data visualization library based on matplotlib
import missingno as msno #Missing data visualization module for Python
import datetime as dt

# %%
# Read in the dataset
df = pd.read_csv('cuisine-francaise.csv')

# %%
df
# Out:
#     Unnamed: 0                               name  \
# 0            0                        Pâte Sucrée
# 1            1                       Basic Crêpes
# 2            2  Rich and Simple French Onion Soup
# 3            3                Chicken Cordon Bleu
# 4            4                   Fondant Potatoes
# 5            5                      French Crêpes
# 6            6                  Lobster Thermidor
# 7            7                      Buche de Noel
# 8            8          Chef John's Crème Fraîche
# 9            9         The Best Lemon Vinaigrette
# 10          10                  Herbs de Provence
# 11          11                 Chocolate Yule Log
# 12          12                       Pastry Cream
# 13          13                     Dessert Crepes
# 14          14               Disney's Ratatouille
# 15          15          Blender Hollandaise Sauce
# 16          16                            Eclairs
# 17          17        Macarons (French Macaroons)
# ...

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df
# Out:
#                                  name  \
# 0                         Pâte Sucrée
# 1                        Basic Crêpes
# 2   Rich and Simple French Onion Soup
# 3                 Chicken Cordon Bleu
# 4                    Fondant Potatoes
# 5                       French Crêpes
# 6                   Lobster Thermidor
# 7                       Buche de Noel
# 8           Chef John's Crème Fraîche
# 9          The Best Lemon Vinaigrette
# 10                  Herbs de Provence
# 11                 Chocolate Yule Log
# 12                       Pastry Cream
# 13                     Dessert Crepes
# 14               Disney's Ratatouille
# 15          Blender Hollandaise Sauce
# 16                            Eclairs
# 17        Macarons (French Macaroons)
# 18                    Quiche Lorraine
# 19                 Lyonnaise Potatoes
# 20       How to Make Bordelaise Sauce
# 21         French Onion Soup Gratinée
# 22                    Omelet in a Bag
# ...

# %%
df.dtypes
# Out:
# name           object
# Description    object
# Calories        int64
# Fat            object
# Carbs          object
# Protein        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         24 non-null     object
#  1   Description  24 non-null     object
#  2   Calories     24 non-null     int64
#  3   Fat          24 non-null     object
#  4   Carbs        24 non-null     object
#  5   Protein      24 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 1.2+ KB

# %%
df['Fat'] = df['Fat'].str.strip("g")

# %%
df['Fat'] = df['Fat'].astype('float')

# %%
df['Fat']
# Out:
# 0     18.0
# 1      9.0
# 2     44.0
# 3     19.0
# 4     11.0
# 5      4.0
# 6     28.0
# 7     18.0
# 8      6.0
# 9     14.0
# 10     0.0
# 11    34.0
# 12     6.0
# 13     8.0
# 14    19.0
# 15    18.0
# 16    28.0
# 17     1.0
# 18    68.0
# 19    20.0
# 20     1.0
# 21    36.0
# 22    34.0
# 23    19.0
# Name: Fat, dtype: float64

# %%
df['Carbs'] = df['Carbs'].str.strip("g")

# %%
df['Carbs'] = df['Carbs'].astype('float')

# %%
df['Protein'] = df['Protein'].str.strip("g")

# %%
df['Protein'] = df['Protein'].astype('float')

# %%
df.dtypes
# Out:
# name            object
# Description     object
# Calories         int64
# Fat            float64
# Carbs          float64
# Protein        float64
# dtype: object

# %%
df.describe()
# Out:
#          Calories        Fat      Carbs    Protein
# count   24.000000  24.000000  24.000000  24.000000
# mean   306.791667  19.291667  20.666667  12.583333
# std    212.194533  15.894979  15.440395  18.379849
# min      4.000000   0.000000   1.000000   0.000000
# 25%    145.250000   7.500000   8.750000   3.750000
# 50%    265.000000  18.000000  18.500000   5.500000
# 75%    478.000000  28.000000  29.500000  10.750000
# max    761.000000  68.000000  56.000000  77.000000

# %%
df.drop('Description', axis=1, inplace=True)

# %%
df.head()
# Out:
#                                 name  Calories   Fat  Carbs  Protein
# 0                        Pâte Sucrée       324  18.0   37.0      4.0
# 1                       Basic Crêpes       216   9.0   26.0      7.0
# 2  Rich and Simple French Onion Soup       586  44.0   28.0     21.0
# 3                Chicken Cordon Bleu       419  19.0   13.0     46.0
# 4                   Fondant Potatoes       239  11.0   34.0      4.0

# %%
df.isna().sum()
# Out:
# name           0
# Description    0
# Calories       0
# Fat            0
# Carbs          0
# Protein        0
# dtype: int64

# %%
df.describe()
# Out:
#          Calories
# count   24.000000
# mean   306.791667
# std    212.194533
# min      4.000000
# 25%    145.250000
# 50%    265.000000
# 75%    478.000000
# max    761.000000

# %%
clones = df[df.duplicated()]

# %%
clones
# Out:
# Empty DataFrame
# Columns: [name, Description, Calories, Fat, Carbs, Protein]
# Index: []
